# %%
pip install pygsheets
pip install gspread oauth2client
import pandas as pd
sheet=pd.read_excel('../input/cloudnine-task/Excel sheet.xlsx')
sheet['date pushed'] = pd.Timestamp('2021-04-06')
import pygsheets
import gspread
from oauth2client.service_account import ServiceAccountCredentials

scope = ['https://spreadsheets.google.com/feeds']
creds = ServiceAccountCredentials.from_json_keyfile_name('../input/jsonkey/secret-melody-309907-0249f0a67620.json', scope)
client = gspread.authorize(creds)

sh = client.open('Test')

#select the first sheet 
wks = sh[0]

#update the first sheet with df, starting at cell B2. 
wks.set_dataframe(sheet,(1,1))
